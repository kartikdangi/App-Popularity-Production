# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max.columns',None)

# %%
df=pd.read_csv(r'C:\Users\harsh\Desktop\Cleaned_Games.csv')

# %%
df.columns
# Out:
# Index(['editors_choice', 'game_types', 'comments', 'price', 'updated', 'size',
#        'installs', 'required_android', 'content_rating', 'game_features',
#        'interactive_elements', 'in_app_products_avg', 'has_website'],
#       dtype='object')

# %%
df['game_types'].value_counts()
# Out:
# action           92
# puzzle           53
# simulation       53
# arcade           52
# adventure        48
# casual           48
# strategy         45
# roleplaying      44
# racing           42
# sports           27
# board            25
# not_specified    22
# education        19
# casino           13
# card             11
# music             4
# word              1
# Name: game_types, dtype: int64

# %%
df['installs'].value_counts()
# Out:
# 10000000      144
# 100000000      85
# 50000000       79
# 1000000        76
# 100000         70
# 5000000        38
# 500000         30
# 10000          22
# 50000          20
# 500000000      11
# 1000            9
# 5000            7
# 1000000000      4
# 100             2
# 50              1
# 10              1
# Name: installs, dtype: int64

# %%
def f(x):
    if x>=100000000:
        return 3
    elif x>=1000000:
        return 2
    else:
        return 1
df['stars']=df['installs'].apply(f)
# as the installs have a very vast range a new variable stars is used which gives more stars to game which have more downloads

# %%
df.describe()
# Out:
#        editors_choice      comments          price      updated        size  \
# count      599.000000  5.990000e+02     599.000000   599.000000  599.000000
# mean         0.168614  1.785737e+06    6142.741235  2019.726210   77.310518
# std          0.374724  6.356179e+06   14869.543441     0.849059   80.500880
# min          0.000000  0.000000e+00       0.000000  2015.000000    1.000000
# 25%          0.000000  1.786300e+04       0.000000  2020.000000   42.000000
# 50%          0.000000  1.078770e+05       0.000000  2020.000000   68.000000
# 75%          0.000000  8.036445e+05    3500.000000  2020.000000   91.000000
# max          1.000000  7.097775e+07  179900.000000  2020.000000  947.000000
#
#            installs  required_android  content_rating  game_features  \
# count  5.990000e+02        599.000000      599.000000     599.000000
# mean   3.953133e+07          4.243740        7.494157       0.580968
# std    1.072370e+08          0.756703        5.185800       0.633279
# ...

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
g = sns.FacetGrid(df, col='content_rating')
g.map(plt.hist,'game_features')

# %% [raw]
# content_rating and game_features are much related because game_features  has all elements like violance, fear  as its values so more such elements more it can be cosidered as highly rated.

# %%
df['price'].value_counts()
# Out:
# 0        395
# 2000      15
# 1000      13
# 7000      12
# 3000       9
#         ...
# 6700       1
# 9000       1
# 20000      1
# 15900      1
# 11903      1
# Name: price, Length: 87, dtype: int64

# %%
df['editors_choice'].value_counts()
# Out:
# 0    498
# 1    101
# Name: editors_choice, dtype: int64

# %%
df['editors_choice'].hist()

# %%
df['comments'].hist(bins=100)

# %%
df['price'].hist(bins=100)

# %%
df['size'].hist(bins=100)

# %%
df['installs'].hist(bins=200)

# %%
df['required_android'].value_counts()
# Out:
# 4    446
# 5    102
# 6     20
# 2     18
# 7     12
# 8      1
# Name: required_android, dtype: int64

# %%
df['required_android'].hist()

# %%
df['content_rating'].value_counts()
# Out:
# 3     294
# 12    128
# 7      93
# 16     46
# 18     38
# Name: content_rating, dtype: int64

# %%
df['content_rating'].hist()

# %%
df['game_features'].value_counts()
# Out:
# 0    295
# 1    263
# 2     38
# 3      3
# Name: game_features, dtype: int64

# %%
df['game_features'].hist()

# %%
df['interactive_elements'].value_counts()
# Out:
# 1    245
# 0    199
# 2    145
# 3     10
# Name: interactive_elements, dtype: int64

# %%
df['interactive_elements'].hist()

# %%
df['in_app_products_avg'].hist()

# %%
df['has_website'].value_counts()
# Out:
# 1    566
# 0     33
# Name: has_website, dtype: int64

# %%
df['has_website'].hist()

# %%
df['stars'].value_counts()
# Out:
# 2    337
# 1    162
# 3    100
# Name: stars, dtype: int64

# %%
df['stars'].hist()

# %%
df['game_types'].value_counts()
# Out:
# action           92
# puzzle           53
# simulation       53
# arcade           52
# adventure        48
# casual           48
# strategy         45
# roleplaying      44
# racing           42
# sports           27
# board            25
# not_specified    22
# education        19
# casino           13
# card             11
# music             4
# word              1
# Name: game_types, dtype: int64

# %%
df['game_types'].hist(xrot=90)

# %%
g = sns.FacetGrid(df, col='has_website')
g.map(plt.hist,'editors_choice')

# %%
game_types = df['game_types'].value_counts()

# %%
fig, ax = plt.subplots(figsize =(20, 14)) 
wedges, texts, autotext = ax.pie(game_types, labels = game_types.index, autopct='%1.1f%%',startangle = 90) 
  
ax.legend(wedges, game_types.index, 
          title ="Game_Type", 
          loc ="center left", 
          bbox_to_anchor =(1, 0, 0.5, 1))

# %%
g = sns.FacetGrid(df, col='game_types')
g.map(plt.hist,'stars')

# %%
g = sns.FacetGrid(df, col='game_types')
g.map(plt.hist,'updated')

# %%
g = sns.FacetGrid(df, col='game_types')
g.map(plt.hist,'comments')

# %% [raw]
# Action games can be considered most famous as they have most downloads,updated and most commented

# %%
df.columns
# Out:
# Index(['editors_choice', 'game_types', 'comments', 'price', 'updated', 'size',
#        'installs', 'required_android', 'content_rating', 'game_features',
#        'interactive_elements', 'in_app_products_avg', 'has_website', 'stars'],
#       dtype='object')

# %%
_df=df.drop(['installs'],axis=1)

# %%
_df.to_csv(r'C:\Users\kartik\Desktop\Final_games.csv',index=False)
